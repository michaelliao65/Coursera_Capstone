# %% [markdown]
# this is for the capstone project

# %% [markdown]
# import pandas

# %%
import pandas as pd

# %% [markdown]
# import numpy

# %%
import numpy as np

# %% [markdown]
# print the following content: Hello Capstone Project Course!

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
